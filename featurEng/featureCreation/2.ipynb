# %%
import pandas as pd
from feature_engine.creation import MathFeatures
from sklearn.datasets import load_breast_cancer
data = load_breast_cancer()
df= pd.DataFrame(data.data, columns =data.feature_names)
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
features = [
    "mean smoothness",
    "mean compactness",
    "mean concavity",
    "mean concave points",
    "mean symmetry"
    
]
df[features].head()
# Out:
#    mean smoothness  mean compactness  mean concavity  mean concave points  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    mean symmetry
# 0         0.2419
# 1         0.1812
# 2         0.2069
# 3         0.2597
# 4         0.1809

# %%
math_func = ["sum","prod","mean","std","max","min"]
new_feature_names = ["sum_f","prod_f","mean_f","std_f","max_f","min_f"]

create = MathFeatures(
    variables=features,
    func=math_func,
    new_variables_names=new_feature_names
)
df_t = create.fit_transform(df)
df_t
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
df_t[features + new_feature_names].head()
# Out:
#    mean smoothness  mean compactness  mean concavity  mean concave points  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    mean symmetry    sum_f    prod_f   mean_f     std_f   max_f    min_f
# 0         0.2419  1.08510  0.000351  0.21702  0.080321  0.3001  0.11840
# 1         0.1812  0.50165  0.000007  0.10033  0.045671  0.1812  0.07017
# 2         0.2069  0.80170  0.000092  0.16034  0.042333  0.2069  0.10960
# 3         0.2597  1.03270  0.000267  0.20654  0.078097  0.2839  0.10520
# 4         0.1809  0.71630  0.000050  0.14326  0.044402  0.1980  0.10030

# %%
df["worst compactness"] - df["mean compactness"]
# Out:
# 0      0.38800
# 1      0.10796
# 2      0.26460
# 3      0.58240
# 4      0.07220
#         ...
# 564    0.09540
# 565    0.08880
# 566    0.20710
# 567    0.59110
# 568    0.02082
# Length: 569, dtype: float64

# %%
df["worst radius"] / df["mean radius"]
# Out:
# 0      1.410784
# 1      1.214876
# 2      1.197054
# 3      1.305604
# 4      1.110892
#          ...
# 564    1.180427
# 565    1.176850
# 566    1.143373
# 567    1.249515
# 568    1.218557
# Length: 569, dtype: float64

# %%
from feature_engine.creation import RelativeFeatures

# %%
features
# Out:
# ['mean smoothness',
#  'mean compactness',
#  'mean concavity',
#  'mean concave points',
#  'mean symmetry']

# %%
references = ["mean radius","mean area"]

creator = RelativeFeatures(
    variables=features,
    reference=references,
    func=["sub","div"]
)
df_t = creator.fit_transform(df)

# %%
df_t.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  mean smoothness_div_mean radius  \
# ...

# %%
creator.feature_names_in_
# Out:
# ['mean radius',
#  'mean texture',
#  'mean perimeter',
#  'mean area',
#  'mean smoothness',
#  'mean compactness',
#  'mean concavity',
#  'mean concave points',
#  'mean symmetry',
#  'mean fractal dimension',
#  'radius error',
#  'texture error',
#  'perimeter error',
#  'area error',
#  'smoothness error',
#  'compactness error',
#  'concavity error',
#  'concave points error',
#  'symmetry error',
#  'fractal dimension error',
#  'worst radius',
#  'worst texture',
#  'worst perimeter',
#  'worst area',
#  'worst smoothness',
#  'worst compactness',
#  'worst concavity',
#  'worst concave points',
#  'worst symmetry',
#  'worst fractal dimension']

# %%
new_features = [f for f in df_t.columns if f not in creator.feature_names_in_]
new_features
# Out:
# ['mean smoothness_sub_mean radius',
#  'mean compactness_sub_mean radius',
#  'mean concavity_sub_mean radius',
#  'mean concave points_sub_mean radius',
#  'mean symmetry_sub_mean radius',
#  'mean smoothness_sub_mean area',
#  'mean compactness_sub_mean area',
#  'mean concavity_sub_mean area',
#  'mean concave points_sub_mean area',
#  'mean symmetry_sub_mean area',
#  'mean smoothness_div_mean radius',
#  'mean compactness_div_mean radius',
#  'mean concavity_div_mean radius',
#  'mean concave points_div_mean radius',
#  'mean symmetry_div_mean radius',
#  'mean smoothness_div_mean area',
#  'mean compactness_div_mean area',
#  'mean concavity_div_mean area',
#  'mean concave points_div_mean area',
#  'mean symmetry_div_mean area']

# %%
df_t[new_features]
# Out:
#      mean smoothness_sub_mean radius  mean compactness_sub_mean radius  \
# 0                          -17.87160                         -17.71240
# 1                          -20.48526                         -20.49136
# 2                          -19.58040                         -19.53010
# 3                          -11.27750                         -11.13610
# 4                          -20.18970                         -20.15720
# ..                               ...                               ...
# 564                        -21.44900                         -21.44410
# 565                        -20.03220                         -20.02660
# 566                        -16.51545                         -16.49770
# 567                        -20.48220                         -20.32300
# 568                         -7.70737                          -7.71638
#
#      mean concavity_sub_mean radius  mean concave points_sub_mean radius  \
# ...
